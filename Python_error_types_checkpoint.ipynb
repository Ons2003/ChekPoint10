# %% [markdown]
# # Rectify the code in each cell and **explain the error in comments**

# %% [markdown]
# ### index error

# %%
mylist=[14, "hello", 967]
mylist[2]
#Item with index 6 in mylist doesn't exist. We can only call index from 0 to 2.
# Out:
# 967

# %%
import pandas
import numpy
#The names of the modules were written wrong

# %% [markdown]
# # syntax error

# %%
print("python errors")
#The parentheses were missing and print was with a capital P
# Out:
# python errors

# %% [markdown]
# # key error

# %%
mydictionnary={True:"hello",False:"bye", '3':"python"}
mydictionnary[True]
#The key we were calling didn't exist in mydictionnary
# Out:
# 'hello'

# %% [markdown]
# # indentation error

# %%
i=14
while i<78:
  print(i)
  i+=1
#Inside a loop we need to indent our code

# %% [markdown]
# # StopIteration

# %%
it=iter([1,2,3])
next(it)
next(it)
next(it)
#next(it)
#The last next() function is useless cause our list is only composed of 3 elements
# Out:
# 3

# %% [markdown]
# # TypeError

# %%
#1
15+15
#2
'15'+'15'
#We can either add two numbers to have a numerical value as a result or concatinate two strings with the "+" sign
# Out:
# '1515'

# %% [markdown]
# # ValueError

# %%
int('33')
#We can't pass a string of alphabets or symbols to the int() function
# Out:
# 33

# %% [markdown]
# # NameError

# %%
python
#python is not defined anywhere as a variable so the interpreter can't find it in memory
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-12-32886514c262> in <module>()
# ----> 1 python
#
# NameError: name 'python' is not defined

# %% [markdown]
# # ZeroDivisionError

# %%
x=19/1
#Dividing by 0 is indefined in mathematics
# Out:
# ZeroDivisionErrorTraceback (most recent call last)
# <ipython-input-15-523d4565e4d9> in <module>()
# ----> 1 x=19/0
#
# ZeroDivisionError: integer division or modulo by zero
